# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\abhij\Desktop\Skills\ML\ML Concepts\Logistic Regression\HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
nan_values = df.isna().any().any()

if nan_values:
    print("There are NaN values in the dataset.")
else:
    print("There are no NaN values in the dataset.")
# Out:
# There are no NaN values in the dataset.

# %%
import matplotlib.pyplot as plt
plt.scatter(df['average_montly_hours'], df['left'])
plt.show()

# %%
plt.scatter(df['time_spend_company'], df['left'])
plt.show()

# %%
plt.scatter(df['promotion_last_5years'], df['left'])
plt.show()

# %%
plt.scatter(df['salary'], df['left'])
plt.show()

# %%
plt.scatter(df['Department'], df['left'])
plt.show()

# %%
plt.scatter(df['Work_accident'], df['left'])
plt.show()

# %%
plt.scatter(df['satisfaction_level'], df['left'])
plt.show()

# %%
plt.scatter(df['last_evaluation'], df['left'])
plt.show()

# %%
plt.scatter(df['promotion_last_5years'], df['left'])
plt.show()

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
df['left'].value_counts()[0]
# Out:
# 11428

# %%
df['left'].value_counts()[1]
# Out:
# 3571

# %%
left = df[df.left==1]

# %%
ret = df[df.left==0]

# %%
df.groupby('left').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# ...

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummies = pd.get_dummies(df['salary']).astype(int)
dummies
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
subdf = pd.concat([subdf,dummies] , axis = 'columns')
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  high  low  medium
# 0         low     0    1       0
# 1      medium     0    0       1
# ...

# %%
subdf = subdf.drop(['salary'] , axis = 'columns')

# %%
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                    0.38                   157                      0     0
# 1                    0.80                   262                      0     0
# 2                    0.11                   272                      0     0
# 3                    0.72                   223                      0     0
# 4                    0.37                   159                      0     0
# ...                   ...                   ...                    ...   ...
# 14994                0.40                   151                      0     0
# 14995                0.37                   160                      0     0
# 14996                0.37                   143                      0     0
# 14997                0.11                   280                      0     0
# 14998                0.37                   158                      0     0
#
#        low  medium
# 0        1       0
# ...

# %%
x = subdf

# %%
y = df.left

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train , y_train)
# Out:
# C:\Users\abhij\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(x_test,y_test)
# Out:
# 0.7782222222222223

# %%
model.predict([[0.69,200,0,0,0,1]])
# Out:
# C:\Users\abhij\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
