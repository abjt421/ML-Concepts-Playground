# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\abhij\Desktop\Skills\ML\ML Concepts\Gradient Descent\test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
# %matplotlib inline
plt.xlabel("math")
plt.ylabel("cs")
plt.scatter(df.math , df.cs , color = "black" , marker = "*")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['math']] , df.cs)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.01773624])

# %%
reg.intercept_
# Out:
# 1.9152193111568891

# %%
# Programme worked both from Linear Regression and Gradient Descent

# %%
# %matplotlib inline
plt.xlabel("Math")
plt.ylabel("CS")
plt.scatter(df.math , df.cs , color = "black" , marker = "*")
plt.plot(df.math, df.cs, color="blue")
